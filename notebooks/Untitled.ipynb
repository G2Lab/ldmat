# %%
import matplotlib

# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
x = pd.read_csv('/tmp/chr1test.csv', index_col=0)

# %%
x
# Out:
#                    1.20000281.G.T  1.20000353.CTTT.C  1.20000475.G.C  \
# 1.20000281.G.T                1.0              0.000           0.000
# 1.20000353.CTTT.C             0.0              1.000           0.642
# 1.20000475.G.C                0.0              0.642           1.000
# 1.20000612.C.T                0.0             -0.251           0.000
# 1.20000822.A.T                0.0              0.000           0.000
# ...                           ...                ...             ...
# 1.20399514.C.T                0.0              0.000           0.000
# 1.20399643.T.C                0.0              0.000           0.000
# 1.20399834.G.A                0.0              0.000           0.000
# 1.20399893.G.A                0.0              0.000           0.000
# 1.20399988.G.A                0.0              0.000           0.000
#
#                    1.20000612.C.T  1.20000822.A.T  1.20001071.T.G  \
# 1.20000281.G.T              0.000             0.0           0.000
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(15,15))
plt.spy(x)

# %%
x = pd.read_csv('/tmp/chr21test2.csv', index_col=0)
fig = plt.figure(figsize=(15,15))
plt.spy(x)

# %%
x = pd.read_csv('/tmp/chr21test3.csv', index_col=0)
fig = plt.figure(figsize=(15,15))
plt.spy(x)

# %%
x = pd.read_csv('/tmp/chr21test4.csv', index_col=0)
fig = plt.figure(figsize=(15,15))
plt.spy(x)

# %%
x = pd.read_csv('/tmp/chr21test5.csv', index_col=0)
fig = plt.figure(figsize=(15,15))
plt.spy(x)

# %%
x = pd.read_csv('/tmp/chr21test6.csv', index_col=0)
fig = plt.figure(figsize=(15,15))
plt.spy(x)
