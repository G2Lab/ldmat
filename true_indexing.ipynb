# %%
import numpy as np
import scipy.sparse as sp
import matplotlib.pyplot as pyplot
import pandas as pd
# %matplotlib inline

# %%
sp_mat = sp.load_npz('chr16_82000001_85000001.npz')

# %%
df = pd.read_csv('chr16_82000001_85000001', delimiter='\t')

# %%
df
# Out:
#                     rsid  chromosome  position allele1 allele2
# 0              rs4888201          16  82000020       A       G
# 1       16:82000233_CA_C          16  82000233      CA       C
# 2            rs188826316          16  82000302       C       A
# 3             rs28376393          16  82000353       G       C
# 4             rs28494471          16  82000380       T       C
# ...                  ...         ...       ...     ...     ...
# 35498        rs562017540          16  84999704       C   CACAT
# 35499  16:84999723_TCA_T          16  84999723     TCA       T
# 35500         rs76369074          16  84999735       A       C
# 35501        rs766021419          16  84999737     TCA       T
# 35502        rs140419567          16  84999969       C       T
#
# [35503 rows x 5 columns]

# %%
base_position = 82000001

# %%
max_position = 85000001

# %%
df['adjusted_position'] = df.position - base_position

# %%
df
# Out:
#                     rsid  chromosome  position allele1 allele2  \
# 0              rs4888201          16  82000020       A       G
# 1       16:82000233_CA_C          16  82000233      CA       C
# 2            rs188826316          16  82000302       C       A
# 3             rs28376393          16  82000353       G       C
# 4             rs28494471          16  82000380       T       C
# ...                  ...         ...       ...     ...     ...
# 35498        rs562017540          16  84999704       C   CACAT
# 35499  16:84999723_TCA_T          16  84999723     TCA       T
# 35500         rs76369074          16  84999735       A       C
# 35501        rs766021419          16  84999737     TCA       T
# 35502        rs140419567          16  84999969       C       T
#
#        adjusted_position
# 0                     19
# 1                    232
# 2                    301
# 3                    352
# 4                    379
# ...                  ...
# 35498            2999703
# 35499            2999722
# 35500            2999734
# 35501            2999736
# 35502            2999968
#
# [35503 rows x 6 columns]

# %%
m = sp_mat.tocsr()

# %%
len(m.indptr)
# Out:
# 35504

# %%
len(m.indices)
# Out:
# 630249218

# %%
m.shape
# Out:
# (35503, 35503)

# %%
def insert_rows(matrix, index, n):
    assert type(matrix) == sp._csr.csr_matrix
    
    num_rows, num_cols = matrix.shape
    matrix._shape = (num_rows + n, num_cols)
    matrix.indptr = np.insert(matrix.indptr, index, [matrix.indptr[index]] * n)

def insert_columns(matrix, index, n):
    assert type(matrix) == sp._csc.csc_matrix

    num_rows, num_cols = matrix.shape
    matrix._shape = (num_rows, num_cols + n)
    matrix.indptr = np.insert(matrix.indptr, index, [matrix.indptr[index]] * n)

# %%
x = m[:10, :10]

# %%
pd.DataFrame(x.todense())
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.500000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.950139  0.500000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2 -0.234925 -0.229400  0.500000  0.000000  0.000000  0.000000  0.000000
# 3  0.105999  0.108776 -0.024126  0.500000  0.000000  0.000000  0.000000
# 4  0.098410  0.101514 -0.025598  0.934986  0.500000  0.000000  0.000000
# 5  0.007848 -0.009516 -0.002619  0.003308  0.003078  0.500000  0.000000
# 6  0.083633  0.080969 -0.103696  0.024018  0.025484  0.002464  0.500000
# 7  0.571500  0.564472 -0.175417 -0.361301 -0.321994 -0.014468  0.154037
# 8  0.011218 -0.006200 -0.002657 -0.001076 -0.003215  0.110411  0.003559
# 9  0.100187  0.100092 -0.022820 -0.050766 -0.054431  0.000784  0.023098
#
#           7         8    9
# 0  0.000000  0.000000  0.0
# 1  0.000000  0.000000  0.0
# 2  0.000000  0.000000  0.0
# 3  0.000000  0.000000  0.0
# 4  0.000000  0.000000  0.0
# 5  0.000000  0.000000  0.0
# 6  0.000000  0.000000  0.0
# 7  0.500000  0.000000  0.0
# 8 -0.034959  0.500000  0.0
# 9 -0.317818  0.001369  0.5

# %%
insert_rows(x, 0, 5)
x = x.tocsc()
insert_columns(x, 0, 5)

# %%
prev_pos = 0

for i, pos_i in enumerate(df.adjusted_position):
    jump = pos_i - prev_pos
    if i % 100 == 0:
        print(f'running row {i}')
    insert_rows(m, i + prev_pos, jump)
# Out:
# running row 0
# running row 100
# running row 200
# running row 300
# running row 400
# running row 500
# running row 600
# running row 700
# running row 800
# running row 900
# running row 1000
# running row 1100
# running row 1200
# running row 1300
# running row 1400
# running row 1500
# running row 1600
# running row 1700
# running row 1800
# running row 1900
# running row 2000
# running row 2100
# running row 2200
# running row 2300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/dx/2gt9564n2mn92wk25_rrrns80000gn/T/ipykernel_5593/1502897847.py in <module>
#       5     if i % 100 == 0:
#       6         print(f'running row {i}')
# ----> 7     insert_rows(m, i + prev_pos, jump)
#       8
#
# /var/folders/dx/2gt9564n2mn92wk25_rrrns80000gn/T/ipykernel_5593/129769969.py in insert_rows(matrix, index, n)
#       4     num_rows, num_cols = matrix.shape
#       5     matrix._shape = (num_rows + n, num_cols)
# ----> 6     matrix.indptr = np.insert(matrix.indptr, index, [matrix.indptr[index]] * n)
#       7
#       8 def insert_columns(matrix, index, n):
#
# <__array_function__ internals> in insert(*args, **kwargs)
#
# /opt/homebrew/lib/python3.9/site-packages/numpy/lib/function_base.py in insert(arr, obj, values, axis)
#    4726         slobj2 = [slice(None)] * ndim
#    4727         slobj2[axis] = slice(index, None)
# -> 4728         new[tuple(slobj)] = arr[tuple(slobj2)]
#    4729         if wrap:
#    4730             return wrap(new)
#
# KeyboardInterrupt:

# %%
full = sp.lil_matrix((max_position - base_position, max_position - base_position))

# %%
full[19, 19] = m[0, 0]

# %%
full

# %%
for i, pos_i in enumerate(df.adjusted_position):
    if i % 100 == 0:
        print(f'finished row {i}')
    for j, pos_j in enumerate(df.adjusted_position):
        if j <= i:
            full[pos_i, pos_j] = m[i,j]

# %%
import numpy as np
import pandas as pd
import scipy.sparse as sparse
def load_ld_npz(ld_prefix):
    
    #load the SNPs metadata
    gz_file = '%s.gz'%(ld_prefix)
    df_ld_snps = pd.read_table(gz_file, sep='\s+')
    df_ld_snps.rename(columns={'rsid':'SNP', 'chromosome':'CHR', 'position':'BP', 'allele1':'A1', 'allele2':'A2'}, inplace=True, errors='ignore')
    assert 'SNP' in df_ld_snps.columns
    assert 'CHR' in df_ld_snps.columns
    assert 'BP' in df_ld_snps.columns
    assert 'A1' in df_ld_snps.columns
    assert 'A2' in df_ld_snps.columns
    df_ld_snps.index = df_ld_snps['CHR'].astype(str) + '.' + df_ld_snps['BP'].astype(str) + '.' + df_ld_snps['A1'] + '.' + df_ld_snps['A2']
# 16.84999737.TCA.T                     0.378113             0.399804
# 16.84999969.C.T                       0.186748             0.165400
#
#                      16.84999723.TCA.T  16.84999735.A.C  16.84999737.TCA.T  \
# 16.82000020.A.G               0.000076         0.001815           0.001815
# 16.82000233.CA.C             -0.000380         0.001229           0.001230
# 16.82000302.C.A              -0.004036        -0.000073          -0.000071
# 16.82000353.G.C               0.000545        -0.002024          -0.002025
# 16.82000380.T.C              -0.000334        -0.000753          -0.000753
# ...                                ...              ...                ...
# 16.84999704.C.CACAT          -0.027975         0.399805           0.399804
# 16.84999723.TCA.T             1.000000        -0.000763          -0.000765
# 16.84999735.A.C              -0.000763         1.000000           0.999764
# 16.84999737.TCA.T            -0.000765         0.999764           1.000000
# 16.84999969.C.T              -0.005001         0.069316           0.069315
#
#                      16.84999969.C.T
# 16.82000020.A.G            -0.000796
# 16.82000233.CA.C           -0.001351
# 16.82000302.C.A            -0.000397
# 16.82000353.G.C            -0.000976
# 16.82000380.T.C            -0.001141
# ...                              ...
# 16.84999704.C.CACAT         0.165400
# 16.84999723.TCA.T          -0.005001
# 16.84999735.A.C             0.069316
# 16.84999737.TCA.T           0.069315
# 16.84999969.C.T             1.000000
#
# [35503 rows x 35503 columns]

# %%
large.min().min()
# Out:
# -1.0

# %%
large.max().max()
# Out:
# 1.0

# %%
cohort_size = 318000
threshold = 1/cohort_size

# %%
(np.abs(large.iloc[0]) > threshold).sum()
# Out:
# 35475

# %%
thresh = large.apply(lambda x: (np.abs(x) > threshold).sum())

# %%
thresh
# Out:
# 16.82000020.A.G        35475
# 16.82000233.CA.C       35475
# 16.82000302.C.A        35479
# 16.82000353.G.C        35478
# 16.82000380.T.C        35484
#                        ...
# 16.84999704.C.CACAT    35469
# 16.84999723.TCA.T      35468
# 16.84999735.A.C        35474
# 16.84999737.TCA.T      35476
# 16.84999969.C.T        35470
# Length: 35503, dtype: int64

# %%
thresh.sum() / (35503**2)
# Out:
# 0.999323266137991

# %%
pyplot.spy(large)

# %%
pyplot.spy(large, precision=0.1)

# %%
pyplot.spy(large, precision=0.01)

# %%
pyplot.spy(large, precision=0.001)

# %%
pyplot.spy(large, precision=0.0001)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/dx/2gt9564n2mn92wk25_rrrns80000gn/T/ipykernel_5593/941846514.py in <module>
# ----> 1 pyplot.spy(large, precision=0.0001)
#
# /opt/homebrew/lib/python3.9/site-packages/matplotlib/pyplot.py in spy(Z, precision, marker, markersize, aspect, origin, **kwargs)
#    3109         Z, precision=0, marker=None, markersize=None, aspect='equal',
#    3110         origin='upper', **kwargs):
# -> 3111     __ret = gca().spy(
#    3112         Z, precision=precision, marker=marker, markersize=markersize,
#    3113         aspect=aspect, origin=origin, **kwargs)
#
# /opt/homebrew/lib/python3.9/site-packages/matplotlib/axes/_axes.py in spy(self, Z, precision, marker, markersize, aspect, origin, **kwargs)
#    7831         if marker is None and markersize is None:
#    7832             Z = np.asarray(Z)
# -> 7833             mask = np.abs(Z) > precision
#    7834
#    7835             if 'cmap' not in kwargs:
#
# KeyboardInterrupt:

# %%
pyplot.spy(r)
